# %% [markdown]
# Crie um programa que tenha uma tupla totalmente preenchida com uma contagem por extenso, de zero até vinte.
# Seu programa devá ler um número pelo teclado (entre 0 e 20) e mostra-ló por extenso.

# %%
Number

# %%
lista=('zero', 'um', 'dois', 'três', 'quatro', ' cinco',
       'seis', 'sete', 'oito', 'nove', 'dez', 'onze',
       'doze', 'treze', 'catorze', 'quinze', 'desesseis', 'desessete',
       'dezoito', 'desenove', 'vinte')


numero=int(input('Digite o número: '))
while numero < 0 or numero > 20:
  numero=int(input('Número inválido! Digite novamente o número: '))
print(f'O valor digitado foi o número {lista[numero].upper()}.')
# Out:
# Digite o número: 3
# O valor digitado foi número TRÊS.
