# %% [markdown]
# Lendo o primeiro termo e a razão de PA, mostrando os 10 primeiros termos da progressão usando a estrutura while.

# %%
primeiroTermo = int(input("Digite o primeiro termo da PA: "))
razao = int (input('Digite a razão da PA: '))
termo = primeiroTermo
contador = 1

while contador <= 10:
  print('{} =>'.format(termo),end=' ')
  termo += razao
  contador += 1

print('FIM')
# Out:
# Digite o primeiro termo da PA: 2
# Digite a razão da PA: 3
# 2 => 5 => 8 => 11 => 14 => 17 => 20 => 23 => 26 => 29 => FIM
