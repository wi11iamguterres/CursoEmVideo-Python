# %% [markdown]
# Faça um programa que leia um número inteiro e diga se ele é ou não é um número primo.

# %%
'''num = int(input('Informe o número: '))

# Um número primo é maior que 1
if num <= 1:
    print(f'{num} não é número primo.')
elif num == 2:
    print(f'{num} é número primo.')
else:
    eh_primo = True
    # Verifica divisores de 2 até num-1
    for c in range(2, num):
        if num % c == 0:
            eh_primo = False
            break  # Encontrou um divisor, não é primo

    if eh_primo:
        print(f'{num} é número primo.')
    else:
        print(f'{num} não é número primo.')'''

#--------------------------------------------------------------

num=int(input("Digite um número inteiro: "))
tot=0

for c in range(1,num+1):
  if num % c == 0:
    print(end='')
    tot +=1
  else:
    print(end='')
  print('{}'.format(c, end=''))
print('O número {} foi divísvel {} vezes.'.format(num,tot))
if tot == 2:
  print('E por isso ele é primo.')
else:
  print('E por isso ele não é primo.')
# Out:
# Digite um número inteiro: 7
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# O número 7 foi divísvel 2 vezes.
# E por isso ele é primo.
