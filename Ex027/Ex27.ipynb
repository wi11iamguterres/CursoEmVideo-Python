# %%
nome=str(input("Digite seu nome completo: ")).strip()
separador=nome.split()
print("Seu primeiro nome é: {}".format(separador[0]))
print("Seu último nome é: {}".format(separador[len(separador)-1]))
# Out:
# Digite seu nome completo: William Guterres Felix
# Seu primeiro nome é: William
# Seu último nome é: Felix
