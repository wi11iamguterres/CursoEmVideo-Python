# %%
from random import randint
numero=int(input("Escreve um número inteiro de 0 a 5: "))
numero_comp=randint(0,5)
if numero == numero_comp:
  print("Acertou, mizerávi!")
else:
  print("Quase. Meu número era {}.".format(numero_comp))
# Out:
# Escreve um número inteiro de 0 a 5: 1
# Quase. Meu número era 4.
