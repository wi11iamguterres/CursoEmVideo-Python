# %%
salario=float(input("Informe o valor do salário: "))
if 0>salario or salario<=1250:
  taxa=15
  aumento=salario*1.15
else:
  taxa=10
  aumento=salario*1.1
print("O valor do salário é R${:.2f}. Com o aumento de {}% o salário ficará R${:.2f}.".format(salario,taxa,aumento))
# Out:
# Informe o valor do salário: 9000
# O valor do salário é R$9000.00. Com o aumento de 10% o salário ficará R$9900.00.
