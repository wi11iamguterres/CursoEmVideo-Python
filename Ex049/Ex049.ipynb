# %% [markdown]
# Faça a tabuada de um número informado pelo teclado

# %%
num=int(input('Informe o número: '))
print('\nA tabuada do número {} é:'.format(num))
for i in range (0,11):
  print('{} x {} = {}'.format(num,i,num*i))
# Out:
# Informe o número: 3
#
# A tabuada do número 3 é:
# 3 x 0 = 0
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
