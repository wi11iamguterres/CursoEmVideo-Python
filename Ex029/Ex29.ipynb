# %%
velocidade=float(input("Informe a velocidade do carro em Km/h: "))
if velocidade > 80:
  print("Veículo multado. O valor da multa será de R${:.2f}".format((velocidade-80)*7))
else:
  print("Veículo dentro do limite de velocidade.")
# Out:
# Informe a velocidade do carro em Km/h: 90
# Veículo multado. O valor da multa será de R$70.00
