# %%
tupla = ('Hamburguer', 'Pizza', 'Suco', 'Pudim','Refri')
lista = []
dicionario = {}

print(tupla[0]+' e '+tupla[2]+'.')
print(tupla[-2])
print(tupla[1:3])

print('='*50)
for comida in tupla:
  print(f"Eu comi {comida}.")
print('='*50)

print('='*50)
for cont in range(0,len(tupla)):
  print(f'Vou comer {tupla[cont]} na posição {cont}.')
print('='*50)

print('='*50)
for pos, tupla in enumerate(tupla):
  print(f'Eu vou comer {tupla} na posição {pos}.')
print('='*50)



a =(1, 2, 3, 4)
b =(9, 7, 22, 0)
c = a + b
print(c)

print(sorted(c))

print(len(c))

print(c.count(22))

print(c.index(22))

pessoa = ('Rafael', 28, 'M',96)
del(pessoa)
print(pessoa)
# Out:
# Hamburguer e Suco.
# Pudim
# ('Pizza', 'Suco')
# ...
# Eu comi Hamburguer.
# Eu comi Pizza.
# Eu comi Suco.
# Eu comi Pudim.
# Eu comi Refri.
# ...
# Vou comer Hamburguer na posição 0.
# Vou comer Pizza na posição 1.
# Vou comer Suco na posição 2.
# Vou comer Pudim na posição 3.
# Vou comer Refri na posição 4.
# ...
# Eu vou comer Hamburguer na posição 0.
# Eu vou comer Pizza na posição 1.
# Eu vou comer Suco na posição 2.
# Eu vou comer Pudim na posição 3.
# Eu vou comer Refri na posição 4.
# ...
# (1, 2, 3, 4, 9, 7, 22, 0)
# [0, 1, 2, 3, 4, 7, 9, 22]
# 8
# 1
# 6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2477017120.py in <cell line: 0>()
#      37 print(c.index(22))
#      38
# ---> 39 print(sorted(c.index(22)))
#
# TypeError: 'int' object is not iterable
