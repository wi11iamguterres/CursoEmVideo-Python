# %% [markdown]
# Exercício Python 39: Faça um programa que leia o ano de nascimento de um jovem e informe, de acordo com a sua idade, se ele ainda vai se alistar ao serviço militar, se é a hora exata de se alistar ou se já passou do tempo do alistamento. Seu programa também deverá mostrar o tempo que falta ou que passou do prazo.

# %%
from datetime import date
while True:
  try:
    ano=int(input("Informe o ano de nascimento: "))
    idade=date.today().year-ano
    if idade < 18:
      print("Você tem {} anos. Ainda falta {} ano(s) para você se alistar ao serviço militar.".format(idade,18-idade))
      break
    elif idade == 18:
      print("Você tem {} anos. É hora de você se alistar ao serviço militar.".format(idade))
      break
    else:
      print("Você tem {} anos. Você deveria ter se alistado há {} ano(s) no serviço militar.".format(idade, idade-18))
      break
  except ValueError:
    print('Carácter inválido!')
# Out:
# Informe o ano de nascimento: a
# Caracter inválido!
# Informe o ano de nascimento: 2000
# Você tem 25 anos. Você deveria ter se alistado há 7 ano(s) no serviço militar.
