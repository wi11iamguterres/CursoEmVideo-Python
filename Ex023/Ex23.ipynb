# %%
num = int(input("Digite um número de 0 a 9999: "))
uni=num//1%10
dez=num//10%10
cen=num//100%10
mil=num//1000%10

print(f"Unidade: {uni}")
print(f"Dezena: {dez}")
print(f"Centena: {cen}")
print(f"Milhar: {mil}")
# Out:
# Digite um número de 0 a 9999: 2349
# Unidade: 9
# Dezena: 4
# Centena: 3
# Milhar: 2
