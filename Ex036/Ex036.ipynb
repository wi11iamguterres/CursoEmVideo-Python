# %% [markdown]
# Escreva um programa para aprovar o empréstimo bancário para a compra de uma casa. Pergunte o valor da casa, o salário do comprador e em quantos anos ele vai pagar. A prestação mensal não pode exceder 30% do salário ou então o empréstimo será negado.

# %%
while True:
  try:
    valor=float(input("Digite o valor da casa: R$"))
    while valor<=0:
      print("Valor inválido.")
      valor=float(input("Digite o valor da casa: R$"))
    salario=float(input("Qual o valor do salário do comprador: R$"))
    while salario<=0:
      print("Salário inválido.")
      salario=float(input("Qual o valor do salário do comprador: R$"))
    tempo=int(input("Em quantos anos será o pagamento: "))
    while tempo<=0:
      print("Tempo de pagamento inválido.")
      tempo=int(input("Em quantos anos será o pagamento: "))
    meses=12*tempo
    prestacao=valor/meses

    if prestacao>0.3*salario:
      print("Empréstimo NEGADO.A parcela ficará no valor de R${:.2f} estando acima dos 30% do salário de R${:.2f}.".format(prestacao,salario))
      break
    elif prestacao<0.3*salario:
      print("Empréstimo APROVADO. A parcela ficará no valor de R${:.2f} estando abaixo dos 30% do salário de R${:.2f}".format(prestacao,salario))
      break
  except ValueError:
    print("Valor inválido.")
# Out:
# Digite o valor da casa: R$a
# Valor inválido.
# Digite o valor da casa: R$9
# Qual o valor do salário do comprador: R$a
# Valor inválido.
# Digite o valor da casa: R$9
# Qual o valor do salário do comprador: R$a
# Valor inválido.
# Digite o valor da casa: R$9
# Qual o valor do salário do comprador: R$9
# Em quantos anos será o pagamento: a
# Valor inválido.
# Digite o valor da casa: R$a
# Valor inválido.
# Digite o valor da casa: R$a
# Valor inválido.
# Digite o valor da casa: R$9
# Qual o valor do salário do comprador: R$9
# Em quantos anos será o pagamento: 9
# Empréstimo APROVADO. A parcela ficará no valor de R$0.08 estando abaixo dos 30% do salário de R$9.00
