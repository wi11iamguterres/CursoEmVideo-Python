# %% [markdown]
# Crie um programa que leia vários números inteiros pelo teclado. No final da execução, mostre a média entre todos os valores e qual foi o maior e a menor valores lidos. O programa deve perguntar ao usuário se ele quer ou não continuar valores.

# %%
soma=0
maior=0
menor=99
cont=0
num=int(input('Digite um número: '))
print('Deseja continuar? [S] ou [N]')
pergunta=str(input()).upper()
while pergunta == 'S':
  cont+=1
  soma=soma+num
  if num > maior:
    maior=num
  if num < menor:
    menor=num
  num=int(input('Digite um número: '))
  print('Deseja continuar? [S] ou [N]')
  pergunta=str(input()).upper()
if pergunta == 'N':
  cont+=1
  soma=soma+num
  if num > maior:
    maior=num
  if num < menor:
    menor=num
  print('\n===========RESULTADO===========')
  print('Média: {}'.format(soma/cont))
  print('Maior: {}'.format(maior))
  print('Menor: {}'.format(menor))
# Out:
# Digite um número: 10
# Deseja continuar? [S] ou [N]
# s
# Digite um número: 20
# Deseja continuar? [S] ou [N]
# s
# Digite um número: 30
# Deseja continuar? [S] ou [N]
# s
# Digite um número: 40
# Deseja continuar? [S] ou [N]
# s
# Digite um número: 50
# Deseja continuar? [S] ou [N]
# n
#
# ===========RESULTADO===========
# Média: 30.0
# Maior: 50
# Menor: 10

# %%
soma=0
maior=0
menor=0
cont=0
Try:
  num=int(input('Digite um número: '))
  while True:
    cont+=1
    soma=soma+num
    if num > maior:
      maior=num
    if num < menor:
      menor=num
    num=int(input('Digite um número: '))
Except ValueError:
  print('Média: {}'.format(soma/cont))
  prinr('Maior: {}'.format(maior))
  print('Menor: {}'.format(menor))
# Out:
#   File "/tmp/ipython-input-3161285122.py", line 5
#     Try:
#         ^
# SyntaxError: invalid syntax
