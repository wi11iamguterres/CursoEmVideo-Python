# %% [markdown]
# Crie um programa que leia vários números inteiros pelo teclado. O programa só vai parar quando o usuário digitar o valor 999, que é a condição de parada. No final, mostre quantos números foram digitados e qual foi a soma entre eles.

# %%
cont=soma=0
while True:
  num=int(input('Digite um número: '))
  if num==999:
    break
  cont+=1
  soma+=num
print('A soma dos números é {} e quantidades de números digitados foi {}.'.format(soma,cont))
# Out:
# Digite um número: 1
# Digite um número: 2
# Digite um número: 3
# Digite um número: 4
# Digite um número: 5
# Digite um número: 6
# Digite um número: 7
# Digite um número: 8
# Digite um número: 9
# Digite um número: 10
# Digite um número: 999
# A soma dos números é 55 e quantidades de números digitados foi 10.
